# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# DATASET LİNK: https://www.kaggle.com/datasets/mohammadrezagim/who-covid-19-global-data

# %%
covid=pd.read_csv(r"C:\Users\selen\OneDrive\Masaüstü\Dataset\Covid\WHO-COVID-19-global-data.csv",encoding="cp1254")
covid
# Out:
#        ï»¿Date_reported Country_code      Country WHO_region  New_cases  \
# 0            2020-01-03           AF  Afghanistan       EMRO          0
# 1            2020-01-04           AF  Afghanistan       EMRO          0
# 2            2020-01-05           AF  Afghanistan       EMRO          0
# 3            2020-01-06           AF  Afghanistan       EMRO          0
# 4            2020-01-07           AF  Afghanistan       EMRO          0
# ...                 ...          ...          ...        ...        ...
# 323263       2023-09-23           ZW     Zimbabwe       AFRO          0
# 323264       2023-09-24           ZW     Zimbabwe       AFRO          0
# 323265       2023-09-25           ZW     Zimbabwe       AFRO          0
# 323266       2023-09-26           ZW     Zimbabwe       AFRO          0
# 323267       2023-09-27           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# 1                      0           0                  0
# 2                      0           0                  0
# 3                      0           0                  0
# 4                      0           0                  0
# ...                  ...         ...                ...
# 323263            265748           0               5718
# 323264            265748           0               5718
# 323265            265748           0               5718
# 323266            265748           0               5718
# 323267            265748           0               5718
#
# [323268 rows x 8 columns]

# %%
covid.columns
# Out:
# Index(['ï»¿Date_reported', 'Country_code', 'Country', 'WHO_region',
#        'New_cases', 'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
covid.drop(columns=["ï»¿Date_reported","Country_code","Cumulative_cases","Cumulative_deaths"],inplace=True)

# %%
covid["New_cases"]=covid["New_cases"].astype("int")
covid["New_deaths"]=covid["New_deaths"].astype("int")

# %%
covid.columns
# Out:
# Index(['Country', 'WHO_region', 'New_cases', 'New_deaths'], dtype='object')

# %% [markdown]
# # Total number of cases and deaths by country

# %%
new_covid=covid.groupby(["Country","WHO_region"])[["New_cases", "New_deaths"]].sum()

# %%
new_covid
# Out:
#                                                                New_cases  \
# Country                                            WHO_region
# Afghanistan                                        EMRO           225983
# Albania                                            EURO           334090
# Algeria                                            AFRO           271852
# American Samoa                                     WPRO             8341
# Andorra                                            EURO            48015
# ...                                                                  ...
# Wallis and Futuna                                  WPRO             3550
# Yemen                                              EMRO            11945
# Zambia                                             AFRO           349287
# Zimbabwe                                           AFRO           265748
# occupied Palestinian territory, including east ... EMRO           703228
#
#                                                                New_deaths
# Country                                            WHO_region
# Afghanistan                                        EMRO              7947
# Albania                                            EURO              3604
# Algeria                                            AFRO              6881
# American Samoa                                     WPRO                34
# Andorra                                            EURO               159
# ...                                                                   ...
# Wallis and Futuna                                  WPRO                 8
# Yemen                                              EMRO              2159
# Zambia                                             AFRO              4069
# Zimbabwe                                           AFRO              5718
# occupied Palestinian territory, including east ... EMRO              5708
#
# [237 rows x 2 columns]

# %%
country_cases=new_covid.groupby("Country")["New_cases"].sum()
country_cases=country_cases.sort_values(ascending=False).head(50) #Since not all values fit in a single graph, we include the 50 highest countries

# %%
country_cases
# Out:
# Country
# United States of America      103436829
# China                          99311610
# India                          44998525
# France                         38997490
# Germany                        38437756
# Brazil                         37720419
# Republic of Korea              34571873
# Japan                          33803572
# Italy                          26007789
# The United Kingdom             24715857
# Russian Federation             23014969
# TÃ¼rkiye                       17004677
# Spain                          13980340
# Viet Nam                       11623571
# Australia                      11600795
# Argentina                      10054576
# Netherlands                     8617412
# Mexico                          7686132
# Iran (Islamic Republic of)      7616791
# Indonesia                       6813429
# Poland                          6520928
# Colombia                        6381318
# Austria                         6081287
# Portugal                        5610180
# Ukraine                         5518385
# Greece                          5370810
# Chile                           5289235
# Malaysia                        5127712
# Israel                          4837580
# Belgium                         4812396
# Thailand                        4757283
# Canada                          4697504
# Czechia                         4647761
# Peru                            4519052
# Switzerland                     4412555
# Philippines                     4112293
# South Africa                    4072533
# Romania                         3440346
# Denmark                         3416698
# Sweden                          2715809
# Singapore                       2579966
# Serbia                          2549375
# Iraq                            2465545
# New Zealand                     2383066
# Hungary                         2204488
# Bangladesh                      2045671
# Slovakia                        1867421
# Georgia                         1855289
# Jordan                          1746997
# Ireland                         1719863
# Name: New_cases, dtype: int32

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=country_cases.index,y=country_cases.values,palette="viridis")

plt.title('Top 50 Countries - Total Number of New Cases')  
plt.xlabel('Countrys')  
plt.ylabel('Total Number of New Cases')  # y-ekseni etiketi
plt.xticks(rotation=90)  
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}')) #Prints the values in the graph as integers
plt.show()

# %%
country_deaths=new_covid.groupby("Country")["New_deaths"].sum()
country_deaths=country_deaths.sort_values(ascending=False).head(50) #Since not all values fit in a single graph, we include the 50 highest countries

# %%
country_deaths
# Out:
# Country
# United States of America            1127152
# Brazil                               704659
# India                                532031
# Russian Federation                   400023
# Mexico                               334586
# The United Kingdom                   229307
# Peru                                 221465
# Italy                                191469
# Germany                              174979
# France                               167985
# Indonesia                            161918
# Iran (Islamic Republic of)           146386
# Colombia                             142977
# Argentina                            130472
# Spain                                121852
# China                                121714
# Poland                               119644
# Ukraine                              109904
# South Africa                         102595
# TÃ¼rkiye                             101419
# Japan                                 74694
# Romania                               68314
# Philippines                           66685
# Chile                                 61606
# Canada                                53147
# Hungary                               48803
# Viet Nam                              43206
# Czechia                               42832
# Bulgaria                              38403
# Greece                                37413
# Malaysia                              37190
# Ecuador                               36042
# Republic of Korea                     35934
# Thailand                              34473
# Belgium                               34339
# Pakistan                              30656
# Bangladesh                            29477
# Tunisia                               29423
# Portugal                              27247
# Iraq                                  25375
# Egypt                                 24830
# Sweden                                24767
# Australia                             23601
# Netherlands                           22986
# Austria                               22534
# Bolivia (Plurinational State of)      22404
# Slovakia                              21167
# Guatemala                             20235
# Paraguay                              19970
# Myanmar                               19494
# Name: New_deaths, dtype: int32

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=country_deaths.index,y=country_deaths.values)
plt.title('Top 50 Countries - Total Number of New Deaths')  
plt.xlabel('Countrys')  
plt.ylabel('Total Number of New Deaths')  
plt.xticks(rotation=90)  
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}')) #Prints the values in the graph as integers
plt.show()

# %% [markdown]
# # Total number of cases and deaths by regions

# %%
region_cases=covid.groupby("WHO_region")["New_cases"].sum().sort_values(ascending=False)

# %%
region_cases
# Out:
# WHO_region
# EURO     276134635
# WPRO     207284734
# AMRO     193286267
# SEARO     61205037
# EMRO      23394122
# AFRO       9569874
# Other          764
# Name: New_cases, dtype: int32

# %%
plt.figure(figsize=(15, 7))
plt.pie(region_cases.values, labels=region_cases.index, autopct='%1.1f%%', startangle=0, pctdistance=0.85)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Drawing a white circle in the center, making it hollow
plt.title('Total Number of New Cases by Region')
plt.show()

# %%
region_deaths=covid.groupby("WHO_region")["New_deaths"].sum()
region_deaths=region_deaths.sort_values(ascending=False)

# %%
region_deaths
# Out:
# WHO_region
# AMRO     2959269
# EURO     2248608
# SEARO     806781
# WPRO      417745
# EMRO      351465
# AFRO      175435
# Other         13
# Name: New_deaths, dtype: int32

# %%
plt.figure(figsize=(15, 7))
plt.pie(region_deaths.values, labels=region_deaths.index, autopct='%1.1f%%', startangle=0, pctdistance=0.85)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Drawing a white circle in the center, making it hollow
plt.title('Total Number of New Deaths by Region')
plt.show()

# %% [markdown]
# # Ratio of cases to deaths by country and region

# %%
new_covid['Death_rate'] = (new_covid['New_deaths'] / new_covid['New_cases']) * 100

# %%
new_covid2=new_covid['Death_rate'].sort_values(ascending=False).head(70)

# %%
new_covid2
# Out:
# Country                           WHO_region
# Yemen                             EMRO          18.074508
# Sudan                             EMRO           7.885237
# Syrian Arab Republic              EMRO           5.508246
# Somalia                           EMRO           4.979147
# Peru                              AMRO           4.900696
# Egypt                             EMRO           4.811801
# Mexico                            AMRO           4.353113
# Bosnia and Herzegovina            EURO           4.056391
# Liberia                           AFRO           3.707440
# Afghanistan                       EMRO           3.516636
# Ecuador                           AMRO           3.370831
# Niger                             AFRO           3.310562
# Myanmar                           SEARO          3.039986
# Malawi                            AFRO           3.021100
# Bulgaria                          EURO           2.954236
# Gambia                            AFRO           2.946301
# North Macedonia                   EURO           2.853239
# Paraguay                          AMRO           2.713732
# Tunisia                           EMRO           2.551066
# Algeria                           AFRO           2.531157
# Chad                              AFRO           2.520135
# South Africa                      AFRO           2.519194
# Sri Lanka                         SEARO          2.510010
# Haiti                             AMRO           2.505608
# Namibia                           AFRO           2.382586
# Indonesia                         SEARO          2.376454
# Honduras                          AMRO           2.344570
# Jamaica                           AMRO           2.307205
# Trinidad and Tobago               AMRO           2.292476
# Mali                              AFRO           2.241192
# Colombia                          AMRO           2.240556
# Bahamas                           AMRO           2.216154
# Senegal                           AFRO           2.214059
# Hungary                           EURO           2.213802
# Cambodia                          WPRO           2.199495
# Zimbabwe                          AFRO           2.151662
# Uganda                            AFRO           2.113557
# El Salvador                       AMRO           2.096062
# Madagascar                        AFRO           2.085468
# Lesotho                           AFRO           2.046970
# Ukraine                           EURO           1.991597
# Romania                           EURO           1.985672
# United Republic of Tanzania       AFRO           1.963879
# Republic of Moldova               EURO           1.949941
# Armenia                           EURO           1.946709
# Pakistan                          EMRO           1.939479
# Iran (Islamic Republic of)        EMRO           1.921885
# Eswatini                          AFRO           1.905665
# Brazil                            AMRO           1.868110
# Bolivia (Plurinational State of)  AMRO           1.853537
# Name: Death_rate, dtype: float64

# %%
countries = new_covid2.index.get_level_values(0) #We need to select lndex because it is #multiindex. A nice alternative to grouping

# %%
region_rate=new_covid2.groupby("WHO_region").sum().sort_values(ascending=False)

# %%
region_rate
# Out:
# WHO_region
# EMRO     51.188006
# AFRO     39.660929
# AMRO     35.062650
# EURO     19.951587
# SEARO     7.926450
# WPRO      2.199495
# Name: Death_rate, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.bar(countries, new_covid2.values, color="red")  # 'Death_rate' sütunu gösteriliyor, isminiz farklıysa uygun isimle değiştirin
plt.title('Deaths rates of countries by number of cases (%)')
plt.xlabel('Countrys')
plt.ylabel('Deaths Rate (%)')
plt.xticks(rotation=90)  # x-ekseni etiketlerini 45 derece döndür
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(region_rate.index, region_rate.values, color="red") 
plt.title('Deaths rates of regions by number of cases (%)')
plt.xlabel('Regions')
plt.ylabel('Deaths Rate (%)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Vaccination Data Fields

# %%
vacc=pd.read_csv(r"C:\Users\selen\OneDrive\Masaüstü\Dataset\Covid\vaccination-data.csv")

# %%
vacc
# Out:
#                     COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0                 Argentina  ARG       AMRO   REPORTING   2022-10-07
# 1                 Australia  AUS       WPRO   REPORTING   2023-09-07
# 2                   Bahrain  BHR       EMRO   REPORTING   2022-12-21
# 3    British Virgin Islands  VGB       AMRO   REPORTING   2023-06-02
# 4                     Egypt  EGY       EMRO   REPORTING   2023-05-21
# ..                      ...  ...        ...         ...          ...
# 224                   Spain  ESP       EURO   REPORTING   2023-06-11
# 225             Switzerland  CHE       EURO   REPORTING   2023-06-11
# 226    Syrian Arab Republic  SYR       EMRO   REPORTING   2023-04-18
# 227             Timor-Leste  TLS      SEARO   REPORTING   2023-06-26
# 228                Viet Nam  VNM       WPRO   REPORTING   2023-06-30
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0           109652736.0                       41324100
# 1            68653247.0                       22201481
# 2             3476633.0                        1241174
# 3               41453.0                          19466
# 4           112673535.0                       56907319
# ..                  ...                            ...
# 224         112837406.0                       41328627
# 225          16755470.0                        6096586
# 226           5090630.0                        3295630
# 227           2019384.0                         884194
# 228         266492149.0                       90272853
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                      242.617                                91.434
# 1                      269.230                                87.065
# 2                      204.319                                72.943
# 3                      137.094                                64.378
# 4                      110.103                                55.609
# ..                         ...                                   ...
# 224                    238.400                                87.131
# 225                    193.600                                70.145
# 226                     29.088                                18.831
# 227                    153.164                                67.063
# 228                    273.779                                92.741
#
#      PERSONS_LAST_DOSE  PERSONS_LAST_DOSE_PER100  VACCINES_USED  \
# 0             37840119                    83.725            NaN
# 1             21610412                    84.747            NaN
# 2              1226796                    72.098            NaN
# 3                18261                    60.393            NaN
# 4             42337175                    41.371            NaN
# ..                 ...                       ...            ...
# 224           37483217                    79.024            NaN
# 225            5723015                    65.847            NaN
# 226            2358365                    13.476            NaN
# 227             799627                    60.649            NaN
# 228           85961564                    88.312            NaN
#
#     FIRST_VACCINE_DATE  NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 0           2020-12-29                         7.0                30810184.0
# 1           2021-02-21                         5.0                14405773.0
# 2           2020-11-04                        11.0                 1008663.0
# 3           2021-02-11                         3.0                    3726.0
# 4           2021-01-24                        10.0                15217352.0
# ..                 ...                         ...                       ...
# 224         2020-12-30                         4.0                26563654.0
# 225         2020-12-23                         6.0                 4996200.0
# 226         2021-04-01                        11.0                   75881.0
# 227         2021-04-07                         4.0                  335563.0
# 228         2021-03-08                         6.0                57975220.0
#
#      PERSONS_BOOSTER_ADD_DOSE_PER100
# 0                             68.170
# 1                             56.493
# 2                             59.278
# 3                             12.323
# 4                             14.870
# ..                               ...
# 224                           56.003
# 225                           57.484
# 226                            0.434
# 227                           25.451
# 228                           59.560
#
# [229 rows x 16 columns]

# %%
vacc.dtypes
# Out:
# COUNTRY                                  object
# ISO3                                     object
# WHO_REGION                               object
# DATA_SOURCE                              object
# DATE_UPDATED                             object
# TOTAL_VACCINATIONS                      float64
# PERSONS_VACCINATED_1PLUS_DOSE             int64
# TOTAL_VACCINATIONS_PER100               float64
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    float64
# PERSONS_LAST_DOSE                         int64
# PERSONS_LAST_DOSE_PER100                float64
# VACCINES_USED                           float64
# FIRST_VACCINE_DATE                       object
# NUMBER_VACCINES_TYPES_USED              float64
# PERSONS_BOOSTER_ADD_DOSE                float64
# PERSONS_BOOSTER_ADD_DOSE_PER100         float64
# dtype: object

# %% [markdown]
# # The first 20 countries to start vaccination

# %%
vacc['FIRST_VACCINE_DATE'] = pd.to_datetime(vacc['FIRST_VACCINE_DATE']) #converted the date value from a string to a date value.

# %%
vacc['FIRST_VACCINE_DATE'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
vacc_date=vacc.groupby("FIRST_VACCINE_DATE")["ISO3"].sum().sort_index(ascending=True).reset_index()

# %%
regex_pattern = r'(.{3})'
vacc_date["ISO3"] = vacc_date["ISO3"].str.extract(regex_pattern) #used the extract method to separate consecutive country codes in the chart.

# %%
vacc_date
# Out:
#     FIRST_VACCINE_DATE ISO3
# 0           2020-07-22  CHN
# 1           2020-11-04  BHR
# 2           2020-11-25  LAO
# 3           2020-12-14  USA
# 4           2020-12-16  DNK
# ..                 ...  ...
# 96          2021-06-08  NIU
# 97          2021-06-30  MCO
# 98          2021-07-20  TKL
# 99          2021-07-28  TZA
# 100         2021-10-18  BDI
#
# [101 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
plt.fill_between(vacc_date["FIRST_VACCINE_DATE"], vacc_date["ISO3"], color='skyblue', alpha=1)
plt.plot(vacc_date["FIRST_VACCINE_DATE"],vacc_date["ISO3"],  marker='o', linestyle='-', color='black')
plt.xlabel('Vaccination Date')
plt.ylabel('Total Number of Vaccinations')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Vaccination rate by country

# %%
vacc["TOTAL_VACCINATIONS"]=vacc["TOTAL_VACCINATIONS"].astype(float)

# %%
pd.options.display.float_format = '{:,.0f}'.format #is used to display numbers in comma separated format.

# %%
total_vac=vacc.groupby("COUNTRY")["TOTAL_VACCINATIONS"].sum()
total_vac_max=total_vac.sort_values(ascending=False).head(30)
total_vac_min=total_vac.sort_values(ascending=False).tail(30)

# %%
fig, ax = plt.subplots(1, 2, figsize=((25), 6))

ax[0].tick_params(axis='x', rotation=90)
sns.barplot(x=total_vac_max.index,y=total_vac_max.values,ax=ax[0])
ax[0].set_title('Top 30 countries with the most vaccinations',fontsize=12, fontweight='bold', color='black')
ax[0].set_xlabel('Countrys',fontsize=12, fontweight='bold', color="black")
ax[0].set_ylabel('Million',fontsize=12, fontweight='bold', color="black")

ax[1].tick_params(axis='x', rotation=90)
sns.barplot(x=total_vac_min.index,y=total_vac_min.values,ax=ax[1])
ax[1].set_title('30 countries with the lowest vaccination rates',fontsize=12, fontweight='bold', color="black")
ax[1].set_xlabel('Countrys',fontsize=12, fontweight='bold', color="black")
ax[1].set_ylabel('Million',fontsize=12, fontweight='bold', color="black")
plt.show()

# %% [markdown]
# # Vaccination rate by region

# %%
vacc_region=vacc.groupby("WHO_REGION")["TOTAL_VACCINATIONS"].sum()
vacc_region
# Out:
# WHO_REGION
# AFRO      638,949,885
# AMRO    2,127,861,011
# EMRO      901,076,717
# EURO    1,727,843,186
# OTHER          71,104
# SEARO   3,350,432,127
# WPRO    4,759,028,447
# Name: TOTAL_VACCINATIONS, dtype: float64

# %%
total_vac_max_region=vacc_region.sort_values(ascending=False).head(30)
total_vac_min_region=vacc_region.sort_values(ascending=False).tail(30)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=total_vac_max_region.index,y=total_vac_max_region.values, palette="colorblind")
plt.title('The most vaccinated region',fontsize=12, fontweight='bold', color='black')
plt.xlabel('Countrys',fontsize=12, fontweight='bold', color="black")
plt.ylabel('Million',fontsize=12, fontweight='bold', color="black")
plt.show()
